# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # EDA

# %%
# Loading data
sales_train = pd.read_csv('data/sales_train.csv')
item_categories = pd.read_csv('data/item_categories.csv')
items = pd.read_csv('data/items.csv')
shops = pd.read_csv('data/shops.csv')
test = pd.read_csv('data/test.csv')
sample_submission = pd.read_csv('data/sample_submission.csv')

# %%
# Adding category_id as a new feature into test dataset
test_feature = pd.merge(test,items,on='item_id')[['ID','shop_id','item_id','item_category_id']]
test_feature = test_feature.sort_values(by='ID')

# %%
# Check for dataset shapes
print(test_feature.shape)
print(sample_submission.shape)
print(sales_train.shape)
# Out:
# (214200, 4)
# (214200, 2)
# (2935849, 6)

# %%
# Transform date format into date time
sales_train['date'] = pd.to_datetime(sales_train['date'])

# %%
# Set date as index for grouping
sales_train=sales_train.set_index('date')

# %%
sales_train.head()
# Out:
#             date_block_num  shop_id  item_id  item_price  item_cnt_day
# date
# 2013-02-01               0       59    22154      999.00           1.0
# 2013-03-01               0       25     2552      899.00           1.0
# 2013-05-01               0       25     2552      899.00          -1.0
# 2013-06-01               0       25     2554     1709.05           1.0
# 2013-01-15               0       25     2555     1099.00           1.0

# %%
sales_train.groupby([pd.Grouper(freq='M'),'item_id'])[['item_cnt_day']].sum()
# Out:
#                     item_cnt_day
# date       item_id
# 2013-01-31 27                3.0
#            28                7.0
#            29                1.0
#            30               33.0
#            31               16.0
#            32              190.0
#            33               49.0
#            34                6.0
#            35               89.0
#            36                2.0
#            37                4.0
#            40                4.0
#            41                8.0
#            42                1.0
#            43                1.0
#            44                7.0
#            45               11.0
#            46                2.0
#            47                6.0
#            48                5.0
#            49                8.0
#            50                2.0
#            51               12.0
#            52                5.0
#            53                8.0
#            54                4.0
# ...

# %%
test_feature
# Out:
#             ID  shop_id  item_id  item_category_id
# 0            0        5     5037                19
# 42           1        5     5320                55
# 84           2        5     5233                19
# 126          3        5     5232                23
# 168          4        5     5268                20
# 210          5        5     5039                23
# 252          6        5     5041                20
# 294          7        5     5046                55
# 336          8        5     5319                55
# 378          9        5     5003                20
# 420         10        5     4806                30
# 462         11        5     4843                20
# 504         12        5     4607                55
# 546         13        5     4869                22
# 588         14        5     4870                23
# 630         15        5     4872                19
# 672         16        5     4874                72
# ...
